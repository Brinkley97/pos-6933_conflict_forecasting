# %% [markdown]
# # Predicting....
#
# ---
#
# ## Notes from class 3.4.26
# - data is online [https://v-dem.net/documents/38/V-Dem_Codebook_v14.pdf] and run R code to get data with ~2k variables ()
# - preprocess 10 variables/indicators (multivariate regression) vdam codebook
#     - I choose x, y, z variables bc ... [_ et al. (date)]
#     - Ex. "Democracy" is a theory: how is this measure? say 10 $\exist$
#         - They give us theory and we choose indicators
# - train 1990 to 2014
#     - cross validation: we choose at least two
# - test 2014 to 2024
# - set seed
# - build a more complex model with specifying hyperparameters
#     -  grid search?
# - build an ensemble model
# - out of bag error rate
# - evaluation: mse, rmse, crps det, crps prob, cov80, cov95, calerr80, sharp80
#     - [continous r... prob score](https://mc-stan.org/loo/reference/crps.html) for distribution --- crps
#     - calibration error (calerr)
#     - 1 to 7 horizons/rows
#     - Actual (y-axis) vs Predicted (x-axis) of log DV
#     - mean prediction by horizon, so 7 diff line plot comparing actual vs predicted

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ## Split Data
#
# - train 1990 to 2014
#     - cross validation: we choose at least two
# - test 2014 to 2024

# %% [markdown]
# ## Train Models

# %% [markdown]
# ## Test Models

# %% [markdown]
# ## Evaluate Models
#
# - evaluation: mse, rmse, crps det, crps prob, cov80, cov95, calerr80, sharp80
#     - [continous r... prob score](https://mc-stan.org/loo/reference/crps.html) for distribution --- crps
#     - calibration error (calerr)
#     - 1 to 7 horizons/rows

# %% [markdown]
# ## Visualize Performance
